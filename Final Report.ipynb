# %% [markdown]
# # Report

# %% [markdown]
# _____________________________________________________________________
# ## **Overview** of the Analysis:
# The purpose of this analysis was to create an algorithm to predict whether applicants for the non-profit foundation Alphabet Soup will be successful for funding. This is a binary classifier that can predict whether applicants will be successful if funded. All in all, the primary purpose is to predict whether funding was executed effectively amongst applicants.

# %% [markdown]
# _____________________________________________________________________
# ## **Results**:

# %% [markdown]
# ### 1. Data Preprocessing:
#    #### - What variable(s) are considered the target(s) for your model?
#    For my model I considered "STATUS", "SPECIAL_CONSIDERATIONS", and "IS_SUCCESSFUL" as the targets for my model. The image/table below lists all features in the dataset and the corresponding unique values in each observation. <app_drop.nunique()>
#
# ![Screen%20Shot%202022-08-18%20at%208.47.00%20PM.png](attachment:Screen%20Shot%202022-08-18%20at%208.47.00%20PM.png)
#
#  After reviewing the image/table above "STATUS", "SPECIAL_CONSIDERATIONS", and "IS_SUCCESSFUL" were considered as the targets for my model as they correspond to only having 2 unique values each which should be more optimal for running the model.

# %% [markdown]
#  #### - What variable(s) are considered the features for your model?
#  The table below indicates "STATUS" and "IS_SUCCESSFUL" as the two more optimal features to use as they are both classified as Dtype: integer. From this information I decided to finally use "IS_SUCCESFUL" as the feature I would use.
#
# ![Screen%20Shot%202022-08-18%20at%209.38.43%20PM.png](attachment:Screen%20Shot%202022-08-18%20at%209.38.43%20PM.png)

# %% [markdown]
#    #### - What variable(s) are neither targets nor features, and should be removed from the input data?
#    The "EIN" and "NAME" features are neither targets nor features for the model and should be removed from the input data. Both columns are identifiers and therefore do not help with predicting whether funding will be executed effectively.

# %% [markdown]
#   ### 2. Compiling, Training, and Evaluating the Model:

# %% [markdown]
#    #### How many neurons, layers, and activation functions did you select for your neural network model, and why?
# Neuron count equaled 40. I decided to put the First Layer layer 15 and Second Layer 25 becuase the Second Hidden Layer should be about 2/3 larger than the First. I decided to use 'relu' and 'sigmoid' due to their reliability as activation functions.

# %% [markdown]
# ![Screen%20Shot%202022-08-18%20at%2010.52.39%20PM.png](attachment:Screen%20Shot%202022-08-18%20at%2010.52.39%20PM.png)

# %% [markdown]
#    #### Were you able to achieve the target model performance?
#    I was not able to achieve target model performance of 75%. The greatest accuracy score I was able to achieve was 0.7312.

# %% [markdown]
#    #### What steps did you take to try and increase model performance?
#    * ##### Attempt 1:
# Creating more bins for rare occurrences in columns to raise the model score.
#
# ![Screen%20Shot%202022-08-18%20at%2011.05.59%20PM.png](attachment:Screen%20Shot%202022-08-18%20at%2011.05.59%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202022-08-18%20at%2010.11.40%20PM.png](attachment:Screen%20Shot%202022-08-18%20at%2010.11.40%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202022-08-18%20at%2010.14.40%20PM.png](attachment:Screen%20Shot%202022-08-18%20at%2010.14.40%20PM.png)

# %% [markdown]
# * ##### Attempt 2:
# Adding an additional layer and changing the units.
#
# ![Screen%20Shot%202022-08-18%20at%2010.21.12%20PM.png](attachment:Screen%20Shot%202022-08-18%20at%2010.21.12%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202022-08-18%20at%2010.25.16%20PM.png](attachment:Screen%20Shot%202022-08-18%20at%2010.25.16%20PM.png)

# %% [markdown]
# * ##### Attempt 3:
# For the final attempt, I am going to copy Attempt 2; adding an additional layer and changing the units. However, in hopes to enhance optimization further I will use a different activation function for the hidden layers and add to the number of epochs to the training regimen.

# %% [markdown]
# ![Screen%20Shot%202022-08-18%20at%2010.28.25%20PM.png](attachment:Screen%20Shot%202022-08-18%20at%2010.28.25%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202022-08-18%20at%2010.31.12%20PM.png](attachment:Screen%20Shot%202022-08-18%20at%2010.31.12%20PM.png)

# %% [markdown]
# _____________________________________________________________________
# ## **Summary**:
#
# Attempt 1 Conclusion: Increasing the binning number resulted in a decrease in accuracy, going from 0.7312 in the orignal model down to 0.7272 in Attempt 1 in the optimization.
#
# Attempt 2 Conclusion: Changing the node numbers resulted in a miniscule decrease in accuracy, going from 0.7312 in the orignal model down to 0.7306 in Attempt 2 in the optimization. However this was a dramatic comeback from the huge decrease seen in Attempt 1 - 0.7272.
#
# Attempt 3 Conclusion: Using the same parameters from Attempt 2 but using a different activation function (tanh) for the hidden layers and adding to the number of epochs to the training regimen (50 to 100) resulted in yet another decrease in accuracy, going from 0.7312 in the orignal model down to 0.7291 in Attempt 3 optimization. This was surprising to see as Attempt 2 had generated such good numbers after Attempt 1 faltered. However, Attempt 3 was still closer to the 73.12% originally seen and the 73.06% seen in Attempt to that one could consider the change to be minimal in affect.

# %% [markdown]
# ### Recommendation:
# Because of the tubular nature of the dataset, a Random Forest classifier could be a better fit for the model. In theory, this data set might be too simple to use a neural network model and a Random Forest classifier might be more suitable since it works well with less complicated data structures. Continuing to run alternative algorithms should be conducted to assure the most optimal model is chosen.
